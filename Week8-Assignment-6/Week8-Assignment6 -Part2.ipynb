# %%
import os
import pandas as pd

# %%
os.chdir('D:/USF/Data Visualization/DataFiles/learn-data-analysis-w-python-master/datasets')

# %%
df=pd.read_csv('gradedata.csv')

# %%
import statsmodels.formula.api as sm
result=sm.ols(formula='grade~age+exercise+hours',data=df).fit()

# %%
#First Regression
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  grade   R-squared:                       0.664
# Model:                            OLS   Adj. R-squared:                  0.664
# Method:                 Least Squares   F-statistic:                     1315.
# Date:                Tue, 07 Apr 2020   Prob (F-statistic):               0.00
# Time:                        00:01:52   Log-Likelihood:                -6300.7
# No. Observations:                2000   AIC:                         1.261e+04
# Df Residuals:                    1996   BIC:                         1.263e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     57.8704      1.321     43.804      0.000      55.279      60.461
# ...

# %%
#second Regression
result=sm.ols(formula='grade~exercise+hours',data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  grade   R-squared:                       0.664
# Model:                            OLS   Adj. R-squared:                  0.664
# Method:                 Least Squares   F-statistic:                     1973.
# Date:                Tue, 07 Apr 2020   Prob (F-statistic):               0.00
# Time:                        00:04:53   Log-Likelihood:                -6300.8
# No. Observations:                2000   AIC:                         1.261e+04
# Df Residuals:                    1997   BIC:                         1.262e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     58.5316      0.447    130.828      0.000      57.654      59.409
# ...

# %%
df.gender[df.gender == 'male'] = 0
df.gender[df.gender == 'female'] = 1
# Out:
# C:\Users\krish\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\krish\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.head()
# Out:
#      fname     lname gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh      1   17         3     10   82.4
# 1   Kadeem  Morrison      0   18         4      4   78.2
# 2     Nash    Powell      0   18         5      9   79.3
# 3  Noelani    Wagner      1   14         2      7   83.2
# 4  Noelani    Cherry      1   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
#Third Regression
result=sm.ols(formula='grade~age+exercise+hours',data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  grade   R-squared:                       0.664
# Model:                            OLS   Adj. R-squared:                  0.664
# Method:                 Least Squares   F-statistic:                     1315.
# Date:                Tue, 07 Apr 2020   Prob (F-statistic):               0.00
# Time:                        00:08:37   Log-Likelihood:                -6300.7
# No. Observations:                2000   AIC:                         1.261e+04
# Df Residuals:                    1996   BIC:                         1.263e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     57.8704      1.321     43.804      0.000      55.279      60.461
# ...

# %% [markdown]
# #### Eventhough we converted gender into numeric variable, there is no difference in R-Squared Value.
