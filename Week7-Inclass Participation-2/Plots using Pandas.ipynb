# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(200,6),index=pd.date_range('1/9/2009',periods=200),columns=list('ABCDEF'))
df.plot(figsize=(20,10)).legend(bbox_to_anchor=(1,1))

# %% [markdown]
# Creating bar plot graph

# %%
df=pd.DataFrame(np.random.rand(20,5),columns=['Jan','Feb','March','April','May'])
df.plot.bar(figsize=(20,10)).legend(bbox_to_anchor=(1.1,1))

# %% [markdown]
# Stacked Bar Plot

# %%
df=pd.DataFrame(np.random.rand(20,5),columns=['Jan','Feb','Mar','April','May'])
df.plot.bar(stacked=True,figsize=(20,10)).legend(bbox_to_anchor=(1.1,1))

# %% [markdown]
# Horizantal Bar Plots

# %%
df=pd.DataFrame(np.random.rand(20,5),columns=['Jan','Feb','Mar','April','May'])
df.plot.barh(stacked=True,figsize=(20,10)).legend(bbox_to_anchor=(1.1,1))

# %% [markdown]
# Histogram Plot

# %%
df=pd.DataFrame(np.random.rand(20,5),columns=['Jan','Feb','Mar','April','May'])
df.plot.hist(bins=20,figsize=(10,8)).legend(bbox_to_anchor=(1.2,1))

# %% [markdown]
# Column Based Histograms

# %%
df=pd.DataFrame({'April':np.random.randn(1000)+1,'May':np.random.randn(1000),'June':np.random.randn(1000)-1},columns=['April','May','June'])
df.hist(bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D3173B7288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D3188DCD08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D318913E08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D31894F0C8>]],
#       dtype=object)

# %% [markdown]
# Creating a Box Plot

# %%
df=pd.DataFrame(np.random.rand(20,5),columns=['Jan','Feb','Mar','April','May'])
df.plot.box()

# %% [markdown]
# Creating an Area Plot

# %%
df=pd.DataFrame(np.random.rand(20,5),columns=['Jan','Feb','Mar','April','May'])
df.plot.area(figsize=(6,4)).legend(bbox_to_anchor=(1.3,1))

# %% [markdown]
# Creating an scatter plot

# %%
df=pd.DataFrame(np.random.rand(20,5),columns=['Jan','Feb','Mar','April','May'])
df.plot.scatter(x='Feb',y='Jan',title='Temparature over two months')
