# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import seaborn as sns
plt.style.use('seaborn-whitegrid')
plt.style.use('classic')
# Create some data
data=np.random.multivariate_normal([0,0],[[5,2],[2,2]],size=2000)
data=pd.DataFrame(data,columns=['x','y'])
#Plotting the data with seaborn
sns.distplot(data['x'])
sns.distplot(data['y'])

# %%
for col in 'xy':
    sns.kdeplot(data[col],shade=True)

# %%
sns.kdeplot(data)
# Out:
# C:\Users\krish\Anaconda3\lib\site-packages\seaborn\distributions.py:679: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
#Joint and Marginal distribution
with sns.axes_style('white'):
    sns.jointplot("x","y",data,kind='kde');

# %%
#Hexagonal based Histogram
with sns.axes_style('white'):
    sns.jointplot("x","y",data,kind='hex');

# %%
#Multidimensional relationship graph
sns.pairplot(data)
