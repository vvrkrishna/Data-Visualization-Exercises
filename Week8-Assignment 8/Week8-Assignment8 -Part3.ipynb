# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
os.chdir('D:/USF/Data Visualization/DataFiles/learn-data-analysis-w-python-master/datasets')
df=pd.read_csv('gradedata.csv')
plt.scatter(df.grade,df['hours'])
plt.xlabel('Grades Achieved')
plt.ylabel('Hours spent')
plt.title('Hours spent on studying vs grades achieved by students')
# Out:
# Text(0.5, 1.0, 'Hours spent on studying vs grades achieved by students')
